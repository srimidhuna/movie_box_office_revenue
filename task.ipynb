# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df = pd.read_csv("regression_datasets_large.xlsx - Movie_Revenue.csv")
X = df[["Marketing_Spend_Cr"]]   
y = df["Box_Office_Revenue_Cr"]  
model = LinearRegression()
model.fit(X, y)
predicted_revenue = model.predict(pd.DataFrame([[10]], columns=["Marketing_Spend_Cr"]))[0]
print("Predicted Revenue for ₹10 Cr Marketing Spend:", round(predicted_revenue, 2), "crore")
predicted_revenue = model.predict(np.array([[10]]))
r2 = model.score(X, y)
print(f"Predicted revenue for ₹10 crore spend: {predicted_revenue}")
print(f"R^2 value: {r2}")
# Out:
# Predicted Revenue for ₹10 Cr Marketing Spend: 97.65 crore
# Predicted revenue for ₹10 crore spend: [97.6450598]
# R^2 value: 0.01116151211842853
# d:\AI Workforce\linear regression\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X["Marketing_Spend_Cr"], y, label="Movies")
plt.plot(X["Marketing_Spend_Cr"], model_simple.predict(X[["Marketing_Spend_Cr"]]),color="red", label="Best Fit Line")
plt.xlabel("Marketing Spend (Cr)")
plt.ylabel("Box Office Revenue (Cr)")
plt.title("Simple Regression: Marketing Spend vs Revenue")
plt.legend()
plt.show()

# %%
predicted_revenue = model.predict(np.array([[10]]))

r2 = model.score(X, y)

print(f"Predicted revenue for ₹10 crore spend: {predicted_revenue}")
print(f"R^2 value: {r2}")
# Out:
# Predicted revenue for ₹10 crore spend: [97.6450598]
# R^2 value: 0.01116151211842853
# d:\AI Workforce\linear regression\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
